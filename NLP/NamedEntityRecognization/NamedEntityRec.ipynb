# %%
sentence = "Hampi or Hampe (Kannada: [hɐmpe]), also referred to as the Group of Monuments at Hampi, is a UNESCO World Heritage Site located in the town of Hampi in Vijayanagara district, east-central Karnataka, India.[2] Hampi predates the Vijayanagara Empire; it is mentioned in the Ramayana and the Puranas of Hinduism as Pampa Devi Tirtha Kshetra.[3][4] Hampi continues as a religious centre, with the Virupaksha Temple, an active Adi Shankara-linked monastery and various monuments belonging to the old city."

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\HhDhage\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\HhDhage\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# True

# %%
tokenword = nltk.word_tokenize(sentence)

# %%
tag_ele = nltk.pos_tag(tokenword)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\HhDhage\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\HhDhage\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_ele)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\HD\AI_Projects\MachineLearningNLP\.venv\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\HD\AI_Projects\MachineLearningNLP\.venv\Lib\site-packages\nltk\tree\tree.py:782, in Tree._repr_svg_(self)
#     781 def _repr_svg_(self):
# --> 782     from svgling import draw_tree
#     784     return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('S', [Tree('GPE', [('Hampi', 'NNP')]), ('or', 'CC'), Tree('GPE', [('Hampe', 'NNP')]), ('(', '('), Tree('PERSON', [('Kannada', 'NNP')]), (':', ':'), ('[', 'NN'), ('hɐmpe', 'NN'), (']', 'NNP'), (')', ')'), (',', ','), ('also', 'RB'), ('referred', 'VBD'), ('to', 'TO'), ('as', 'IN'), ('the', 'DT'), ('Group', 'NNP'), ('of', 'IN'), Tree('ORGANIZATION', [('Monuments', 'NNP')]), ('at', 'IN'), Tree('ORGANIZATION', [('Hampi', 'NNP')]), (',', ','), ('is', 'VBZ'), ('a', 'DT'), Tree('ORGANIZATION', [('UNESCO', 'NNP')]), ('World', 'NNP'), ('Heritage', 'NNP'), ('Site', 'NNP'), ('located', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('town', 'NN'), ('of', 'IN'), Tree('GPE', [('Hampi', 'NNP')]), ('in', 'IN'), Tree('GPE', [('Vijayanagara', 'NNP')]), ('district', 'NN'), (',', ','), ('east-central', 'JJ'), Tree('PERSON', [('Karnataka', 'NNP')]), (',', ','), Tree('GPE', [('India', 'NNP')]), ('.', '.'), ('[', 'CC'), ('2', 'CD'), (']', 'JJ'), Tree('ORGANIZATION', [('Hampi', 'NNP')]), ('predates', 'VBZ'), ('the', 'DT'), Tree('FACILITY', [('Vijayanagara', 'NNP'), ('Empire', 'NNP')]), (';', ':'), ('it', 'PRP'), ('is', 'VBZ'), ('mentioned', 'VBN'), ('in', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Ramayana', 'NNP')]), ('and', 'CC'), ('the', 'DT'), Tree('ORGANIZATION', [('Puranas', 'NNP')]), ('of', 'IN'), Tree('GPE', [('Hinduism', 'NNP')]), ('as', 'IN'), Tree('PERSON', [('Pampa', 'NNP'), ('Devi', 'NNP'), ('Tirtha', 'NNP'), ('Kshetra', 'NNP')]), ('.', '.'), ('[', 'CC'), ('3', 'CD'), (']', 'JJ'), ('[', '$'), ('4', 'CD'), (']', 'NNP'), ('Hampi', 'NNP'), ('continues', 'VBZ'), ('as', 'IN'), ('a', 'DT'), ('religious', 'JJ'), ('centre', 'NN'), (',', ','), ('with', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Virupaksha', 'NNP'), ('Temple', 'NNP')]), (',', ','), ('an', 'DT'), ('active', 'JJ'), ('Adi', 'NNP'), ('Shankara-linked', 'JJ'), ('monastery', 'NN'), ('and', 'CC'), ('various', 'JJ'), ('monuments', 'NNS'), ('belonging', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('old', 'JJ'), ('city', 'NN'), ('.', '.')])

# %%
nltk.ne_chunk(tag_ele).draw()
